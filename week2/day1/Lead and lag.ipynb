# %%
# %sql
CREATE or replace TABLE costomers (
    id INT NOT NULL,
    first_name  VARCHAR(50) NOT NULL,
    country     VARCHAR(50),
    score       INT,
    CONSTRAINT PK_customers PRIMARY KEY (id)
);

-- Insert customers data
INSERT INTO costomers (id, first_name, country, score) VALUES
    (1, 'Maria',     'Germany', 350),
    (2, ' John',     'USA',     900),
    (3, 'Georg',   'UK',      750),
    (4, 'Martin', 'Germany', 500),
    (5, 'Peter',   'USA',     0);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
CREATE or REPLACE TABLE olders (
    order_id    INT NOT NULL,
    customer_id INT NOT NULL,
    order_date  DATE,
    sales    INT,
    CONSTRAINT PK_orders PRIMARY KEY (order_id)
);


-- Insert orders data
INSERT INTO olders (order_id, customer_id, order_date, sales) VALUES
    (1001, 1, '2021-01-11', 35),
    (1002, 2, '2021-04-05', 15),
    (1003, 3, '2021-06-18', 20),
    (1004, 6, '2021-08-31', 10);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>4</td><td>4</td></tr></tbody></table></div>

# %%
# %sql
create schema workspace.sales1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE TABLE Sales1.Costomers (
    CustomerID INT NOT NULL,
    FirstName VARCHAR(50),
    LastName VARCHAR(50),
    Country VARCHAR(50),
    Score INT,
    CONSTRAINT PK_costomers PRIMARY KEY (CustomerID)
);


-- Insert data into Customer table
INSERT INTO Sales1.Costomers 
VALUES
    (1, 'Jossef', 'Goldberg', 'Germany', 350),
    (2, 'Kevin', 'Brown', 'USA', 900),
    (3, 'Mary', NULL, 'USA', 750),
    (4, 'Mark', 'Schwarz', 'Germany', 500),
    (5, 'Anna', 'Adams', 'USA', NULL);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
CREATE TABLE Sales1.employees2 (
    EmployeeID INT NOT NULL,
    FirstName VARCHAR(50),
    LastName VARCHAR(50),
    Department VARCHAR(50),
    BirthDate DATE,
    Gender CHAR(1),
    Salary INT,
	ManagerID INT,
	CONSTRAINT PK_employees2 PRIMARY KEY (EmployeeID)
);


INSERT INTO Sales1.Employees2
VALUES
    (1, 'Frank', 'Lee', 'Marketing', '1988-12-05', 'M', 55000, null),
    (2, 'Kevin', 'Brown', 'Marketing', '1972-11-25', 'M', 65000, 1),
    (3, 'Mary', null, 'Sales', '1986-01-05', 'F', 75000, 1),
    (4, 'Michael', 'Ray', 'Sales', '1977-02-10', 'M', 90000, 2),
    (5, 'Carol', 'Baker', 'Sales', '1982-02-11', 'F', 55000, 3);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
CREATE TABLE Sales1.Products1 (
    ProductID INT NOT NULL,
    Product VARCHAR(50),
    Category VARCHAR(50),
    Price INT,
	CONSTRAINT PK_products1 PRIMARY KEY (ProductID)
);

INSERT INTO Sales1.Products1 (ProductID, Product, Category, Price)
VALUES
    (101, 'Bottle', 'Accessories', 10),
    (102, 'Tire', 'Accessories', 15),
    (103, 'Socks', 'Clothing', 20),
    (104, 'Caps', 'Clothing', 25),
    (105, 'Gloves', 'Clothing', 30);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
CREATE or replace TABLE Sales1.Orders1 (
    OrderID INT NOT NULL,
	ProductID INT,
    CustomerID INT,
    SalesPersonID INT,
    OrderDate DATE,
    ShipDate DATE,
    OrderStatus VARCHAR(50),
	ShipAddress VARCHAR(255),
	BillAddress VARCHAR(255),
    Quantity INT,
    Sales INT,
	CreationTime TIMESTAMP,
	CONSTRAINT PK_orders1 PRIMARY KEY (OrderID)
);

INSERT INTO Sales1.Orders1
VALUES
    (1,  101, 2, 3, '2025-01-01', '2025-01-05', 'Delivered','9833 Mt. Dias Blv.', '1226 Shoe St.',  1, 10, '2025-01-01T12:34:56'),
    (2,  102, 3, 3, '2025-01-05', '2025-01-10', 'Shipped','250 Race Court',NULL, 1, 15, '2025-01-05T23:22:04'),
    (3,  101, 1, 5, '2025-01-10', '2025-01-25', 'Delivered','8157 W. Book','8157 W. Book', 2, 20, '2025-01-10T18:24:08'),
    (4,  105, 1, 3, '2025-01-20', '2025-01-25', 'Shipped', '5724 Victory Lane', '', 2, 60, '2025-01-20T05:50:33'),
    (5,  104, 2, 5, '2025-02-01', '2025-02-05', 'Delivered',NULL, NULL, 1, 25, '2025-02-01T14:02:41'),
    (6,  104, 3, 5, '2025-02-05', '2025-02-10', 'Delivered','1792 Belmont Rd.',NULL, 2, 50, '2025-02-06T15:34:57'),
    (7,  102, 1, 1, '2025-02-15', '2025-02-27', 'Delivered','136 Balboa Court', '', 2, 30, '2025-02-16T06:22:01'),
    (8,  101, 4, 3, '2025-02-18', '2025-02-27', 'Shipped','2947 Vine Lane','4311 Clay Rd', 3, 90, '2025-02-18T10:45:22'),
    (9,  101, 2, 3, '2025-03-10', '2025-03-15', 'Shipped','3768 Door Way', '', 2, 20,'2025-03-10T12:59:04'),
    (10, 102, 3, 5, '2025-03-15', '2025-03-20', 'Shipped',NULL, NULL, 0, 60,'2025-03-16T23:25:15');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>10</td><td>10</td></tr></tbody></table></div>

# %%
# %sql
CREATE or replace TABLE Sales1.OrdersArchive (
    OrderID INT,
	ProductID INT,
    CustomerID INT,
    SalesPersonID INT,
    OrderDate DATE,
    ShipDate DATE,
    OrderStatus VARCHAR(50),
	ShipAddress VARCHAR(255),
	BillAddress VARCHAR(255),
    Quantity INT,
    Sales INT,
	CreationTime TIMESTAMP
);

INSERT INTO Sales1.OrdersArchive 
VALUES
    (1, 101,2 , 3, '2024-04-01', '2024-04-05', 'Shipped','123 Main St', '456 Billing St', 1, 10, '2024-04-01T12:34:56'),
    (2, 102,3 , 3, '2024-04-05', '2024-04-10', 'Shipped','456 Elm St', '789 Billing St', 1, 15, '2024-04-05T23:22:04'),
    (3, 101, 1, 4, '2024-04-10', '2024-04-25', 'Shipped','789 Maple St','789 Maple St', 2, 20, '2024-04-10T18:24:08'),
    (4, 105,1 , 3, '2024-04-20', '2024-04-25', 'Shipped',   '987 Victory Lane', '', 2, 60, '2024-04-20T05:50:33'),
    (4, 105,1 , 3, '2024-04-20', '2024-04-25', 'Delivered', '987 Victory Lane', '', 2, 60, '2024-04-20T14:50:33'),
    (5, 104,2 , 5, '2024-05-01', '2024-05-05', 'Shipped','345 Oak St', '678 Pine St', 1, 25, '2024-05-01T14:02:41'),
    (6, 104, 3, 5, '2024-05-05', '2024-05-10', 'Delivered','543 Belmont Rd.',NULL, 2, 50, '2024-05-06T15:34:57'),
    (6, 104, 3, 5, '2024-05-05', '2024-05-10', 'Delivered','543 Belmont Rd.','3768 Door Way', 2, 50, '2024-05-07T13:22:05'),
    (6, 101, 3, 5, '2024-05-05', '2024-05-10', 'Delivered','543 Belmont Rd.','3768 Door Way', 2, 50, '2024-05-12T20:36:55'),
	(7, 102,3 , 5, '2024-06-15', '2024-06-20', 'Shipped','111 Main St', '222 Billing St', 0, 60,'2024-06-16T23:25:15');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>10</td><td>10</td></tr></tbody></table></div>

# %%
# %sql
SELECT *,
       currentmonthSales - previousmonthSales AS MOM_Change,
       ROUND(
           (currentmonthSales - previousmonthSales) * 100.0 / previousmonthSales, 
           1
       ) AS MOM_Perc
FROM (
    SELECT 
        MONTH(orderdate) AS ordermonth,
        SUM(sales) AS currentmonthSales,
        LAG(SUM(sales)) OVER (ORDER BY MONTH(orderdate)) AS previousmonthSales
    FROM sales.orders1
    GROUP BY MONTH(orderdate)
) t;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ordermonth</th><th>currentmonthSales</th><th>previousmonthSales</th><th>MOM_Change</th><th>MOM_Perc</th></tr></thead><tbody><tr><td>1</td><td>105</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2</td><td>195</td><td>105</td><td>90</td><td>85.7</td></tr><tr><td>3</td><td>80</td><td>195</td><td>-115</td><td>-59.0</td></tr></tbody></table></div>

# %%
# %sql
SELECT 
    customerid,
    AVG(DaysUntilNextOrder) AS avgdays,
    RANK() OVER(ORDER BY COALESCE(AVG(DaysUntilNextOrder),99999)) AS RankAvg
FROM (
    SELECT 
        customerid,
        DATEDIFF(day, orderdate,
            LEAD(orderdate) OVER(PARTITION BY customerid ORDER BY orderdate)
        ) AS DaysUntilNextOrder
    FROM sales.orders1
) t
GROUP BY customerid;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customerid</th><th>avgdays</th><th>RankAvg</th></tr></thead><tbody><tr><td>1</td><td>18.0</td><td>1</td></tr><tr><td>2</td><td>34.0</td><td>2</td></tr><tr><td>3</td><td>34.5</td><td>3</td></tr><tr><td>4</td><td>null</td><td>4</td></tr></tbody></table></div>

# %%
# %sql
SELECT *,
       RANK() OVER(ORDER BY totalsales DESC) AS CustomerRank
FROM (
    SELECT 
        customerid,
        SUM(sales) AS totalsales
    FROM sales.orders1
    GROUP BY customerid
) t;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customerid</th><th>totalsales</th><th>CustomerRank</th></tr></thead><tbody><tr><td>3</td><td>125</td><td>1</td></tr><tr><td>1</td><td>110</td><td>2</td></tr><tr><td>4</td><td>90</td><td>3</td></tr><tr><td>2</td><td>55</td><td>4</td></tr></tbody></table></div>

# %%
# %sql
SELECT *
FROM (
    SELECT 
        productid,
        price,
        AVG(price) OVER() AS avgprice
    FROM sales.products1
) t
WHERE price > avgprice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>productid</th><th>price</th><th>avgprice</th></tr></thead><tbody><tr><td>104</td><td>25</td><td>20.0</td></tr><tr><td>105</td><td>30</td><td>20.0</td></tr></tbody></table></div>

# %%
# %sql
SELECT c.*, o.totalorders
FROM sales.customers c
LEFT JOIN (
    SELECT 
        customerid,
        COUNT(*) AS totalorders
    FROM sales.orders1
    GROUP BY customerid
) o
ON c.customerid = o.customerid;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th>FirstName</th><th>LastName</th><th>Country</th><th>Score</th><th>totalorders</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT 
    productid,
    product,
    price,
    (SELECT COUNT(*) FROM sales.orders1) AS TotalOrders
FROM sales.products1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>productid</th><th>product</th><th>price</th><th>TotalOrders</th></tr></thead><tbody><tr><td>101</td><td>Bottle</td><td>10</td><td>10</td></tr><tr><td>102</td><td>Tire</td><td>15</td><td>10</td></tr><tr><td>103</td><td>Socks</td><td>20</td><td>10</td></tr><tr><td>104</td><td>Caps</td><td>25</td><td>10</td></tr><tr><td>105</td><td>Gloves</td><td>30</td><td>10</td></tr></tbody></table></div>

# %%
# %sql
SELECT 
    productid,
    price 
FROM sales.products1
WHERE price > (SELECT AVG(price) FROM sales.products1);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>productid</th><th>price</th></tr></thead><tbody><tr><td>104</td><td>25</td></tr><tr><td>105</td><td>30</td></tr></tbody></table></div>

# %%
# %sql
SELECT *
FROM sales.orders1
WHERE customerid IN (
    SELECT customerid
    FROM sales.customers
    WHERE country = 'Germany'
);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>OrderID</th><th>ProductID</th><th>CustomerID</th><th>SalesPersonID</th><th>OrderDate</th><th>ShipDate</th><th>OrderStatus</th><th>ShipAddress</th><th>BillAddress</th><th>Quantity</th><th>Sales</th><th>CreationTime</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT 
    employeeid,
    firstname,
    salary
FROM sales.employees2
WHERE gender = 'F'
AND salary > (
    SELECT MIN(salary)
    FROM sales.employees2
    WHERE gender = 'M'
);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employeeid</th><th>firstname</th><th>salary</th></tr></thead><tbody><tr><td>3</td><td>Mary</td><td>75000</td></tr></tbody></table></div>

# %%
# %sql
SELECT 
    employeeid,
    firstname,
    salary
FROM sales.employees2
WHERE gender = 'F'
AND salary > (
    SELECT MAX(salary)
    FROM sales.employees2
    WHERE gender = 'M'
);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employeeid</th><th>firstname</th><th>salary</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
WITH cte_totalsales AS (
    SELECT 
        customerid,
        SUM(Sales) AS totalsales
    FROM sales.orders1
    GROUP BY customerid
)
SELECT 
    c.customerid,
    c.firstname,
    c.lastname,
    cts.totalsales
FROM sales.customers c
LEFT JOIN cte_totalsales cts
ON c.customerid = cts.customerid;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customerid</th><th>firstname</th><th>lastname</th><th>totalsales</th></tr></thead><tbody></tbody></table></div>
