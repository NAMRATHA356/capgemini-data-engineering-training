# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.window import Window

spark = SparkSession.builder.getOrCreate()

customers = spark.createDataFrame([(1, 'Cust1', 25, 'Bangalore'), (2, 'Cust2', 52, 'Chennai'), (3, 'Cust3', 46, 'Bangalore'), (4, 'Cust4', 58, 'Hyderabad'), (5, 'Cust5', 36, 'Hyderabad'), (6, 'Cust6', 50, 'Mumbai'), (7, 'Cust7', 43, 'Chennai'), (8, 'Cust8', 32, 'Chennai'), (9, 'Cust9', 47, 'Hyderabad'), (10, 'Cust10', 39, 'Mumbai'), (11, 'Cust11', 42, 'Hyderabad'), (12, 'Cust12', 33, 'Bangalore'), (13, 'Cust13', 57, 'Hyderabad'), (14, 'Cust14', 60, 'Mumbai'), (15, 'Cust15', 30, 'Hyderabad'), (16, 'Cust16', 56, 'Bangalore'), (17, 'Cust17', 51, 'Chennai'), (18, 'Cust18', 36, 'Mumbai'), (19, 'Cust19', 35, 'Hyderabad'), (20, 'Cust20', 43, 'Bangalore'), (21, 'Cust21', 45, 'Chennai'), (22, 'Cust22', 40, 'Hyderabad'), (23, 'Cust23', 30, 'Mumbai'), (24, 'Cust24', 24, 'Mumbai'), (25, 'Cust25', 49, 'Bangalore'), (26, 'Cust26', 31, 'Mumbai'), (27, 'Cust27', 25, 'Chennai'), (28, 'Cust28', 46, 'Bangalore'), (29, 'Cust29', 34, 'Chennai'), (30, 'Cust30', 35, 'Mumbai'), (31, 'Cust31', 20, 'Chennai'), (32, 'Cust32', 35, 'Bangalore'), (33, 'Cust33', 41, 'Mumbai'), (34, 'Cust34', 22, 'Bangalore'), (35, 'Cust35', 59, 'Hyderabad'), (36, 'Cust36', 32, 'Chennai'), (37, 'Cust37', 59, 'Hyderabad'), (38, 'Cust38', 35, 'Chennai'), (39, 'Cust39', 29, 'Mumbai'), (40, 'Cust40', 26, 'Bangalore'), (41, 'Cust41', 51, 'Chennai'), (42, 'Cust42', 25, 'Mumbai'), (43, 'Cust43', 52, 'Mumbai'), (44, 'Cust44', 44, 'Hyderabad'), (45, 'Cust45', 55, 'Mumbai'), (46, 'Cust46', 31, 'Hyderabad'), (47, 'Cust47', 24, 'Bangalore'), (48, 'Cust48', 60, 'Mumbai'), (49, 'Cust49', 26, 'Bangalore'), (50, 'Cust50', 58, 'Bangalore'), (51, 'Cust51', 60, 'Chennai'), (52, 'Cust52', 47, 'Chennai'), (53, 'Cust53', 48, 'Mumbai'), (54, 'Cust54', 25, 'Chennai'), (55, 'Cust55', 27, 'Mumbai'), (56, 'Cust56', 34, 'Chennai'), (57, 'Cust57', 54, 'Bangalore'), (58, 'Cust58', 29, 'Bangalore'), (59, 'Cust59', 51, 'Chennai'), (60, 'Cust60', 39, 'Hyderabad')], ["customer_id","name","age","city"])
policies = policies.withColumn("start_date", to_date(col("start_date")))
claims = claims.withColumn("claim_date", to_date(col("claim_date")))

df = customers.join(policies,"customer_id","left") \
             .join(claims,"policy_id","left") \
             .join(policy_agent,"policy_id","left") \
             .join(agents,"agent_id","left")

df.groupBy("customer_id").agg(sum("premium").alias("total_premium"),
                              sum("claim_amount").alias("total_claim")).show()
# Out:
# +-----------+-------------+-----------+
# |customer_id|total_premium|total_claim|
# +-----------+-------------+-----------+
# |          3|        -4360|       NULL|
# |          4|        33438|      23940|
# |          6|        -3629|      12245|
# |          2|         -872|       2059|
# |          7|         NULL|       NULL|
# |          5|       -17508|      13066|
# |          1|        42130|      43744|
# |          9|        10514|       NULL|
# |         11|        31523|       5620|
# |         14|        33192|       7541|
# |         13|         NULL|       NULL|
# |         12|        25754|       6667|
# |          8|        19956|      14391|
# |         15|        22762|       NULL|
# |         10|        -2972|       3636|
# |         17|        52287|      48090|
# |         19|        34772|      36814|
# |         20|         NULL|       NULL|
# |         22|         NULL|       NULL|
# |         16|         4276|      37169|
# +-----------+-------------+-----------+
# only showing top 20 rows

# %%
df.filter("premium < 0 OR claim_amount < 0").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>agent_id</th><th>policy_id</th><th>customer_id</th><th>name</th><th>age</th><th>city</th><th>policy_type</th><th>premium</th><th>start_date</th><th>claim_id</th><th>claim_amount</th><th>claim_date</th><th>status</th><th>name</th><th>region</th></tr></thead><tbody><tr><td>3</td><td>163</td><td>2</td><td>Cust2</td><td>52</td><td>Chennai</td><td>Auto</td><td>-872</td><td>2023-05-05</td><td>264</td><td>2059</td><td>2023-04-03</td><td>Rejected</td><td>Agent3</td><td>West</td></tr><tr><td>1</td><td>132</td><td>3</td><td>Cust3</td><td>46</td><td>Bangalore</td><td>Health</td><td>-4360</td><td>2023-07-28</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Agent1</td><td>South</td></tr><tr><td>12</td><td>141</td><td>5</td><td>Cust5</td><td>36</td><td>Hyderabad</td><td>Auto</td><td>-1909</td><td>2023-04-28</td><td>271</td><td>10757</td><td>2023-01-30</td><td>Approved</td><td>Agent12</td><td>West</td></tr><tr><td>6</td><td>164</td><td>6</td><td>Cust6</td><td>50</td><td>Mumbai</td><td>Health</td><td>-3629</td><td>2023-01-29</td><td>272</td><td>12245</td><td>2023-07-14</td><td>Pending</td><td>Agent6</td><td>East</td></tr><tr><td>9</td><td>124</td><td>5</td><td>Cust5</td><td>36</td><td>Hyderabad</td><td>Life</td><td>-3927</td><td>2023-05-12</td><td>null</td><td>null</td><td>null</td><td>null</td><td>
       NULL|   NULL|      NULL|    NULL|        NULL|      NULL|  NULL|NULL|  NULL|
# |    NULL|     NULL|         51|Cust51| 60|  Chennai|       NULL|   NULL|      NULL|    NULL|        NULL|      NULL|  NULL|NULL|  NULL|
# |    NULL|     NULL|         57|Cust57| 54|Bangalore|       NULL|   NULL|      NULL|    NULL|        NULL|      NULL|  NULL|NULL|  NULL|
# +--------+---------+-----------+------+---+---------+-----------+-------+----------+--------+------------+----------+------+----+------+

# %%
df.select("city").distinct().show()
# Out:
# +---------+
# |     city|
# +---------+
# |Bangalore|
# |  Chennai|
# |Hyderabad|
# |   Mumbai|
# +---------+

# %%
customers.printSchema()
policies.printSchema()
claims.printSchema()
agents.printSchema()
policy_agents.printSchema()
# Out:
# root
#  |-- customer_id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: long (nullable = true)
#  |-- city: string (nullable = true)
#
# root
#  |-- policy_id: long (nullable = true)
#  |-- customer_id: long (nullable = true)
#  |-- policy_type: string (nullable = true)
#  |-- premium: long (nullable = true)
#  |-- start_date: date (nullable = true)
#
# root
#  |-- claim_id: long (nullable = true)
#  |-- policy_id: long (nullable = true)
#  |-- claim_amount: long (nullable = true)
#  |-- claim_date: date (nullable = true)
#  |-- status: string (nullable = true)
#
# root
#  |-- agent_id: long (nullable = true)
#  |-- agent_name: string (nullable = true)
#  |-- region: string (nullable = true)
#
# root
#  |-- policy_id: long (nullable = true)
#  |-- agent_id: long (nullable = true)

# %%
print("Customers:", customers.count())
print("Policies:", policies.count())
print("Claims:", claims.count())
print("Agents:", agents.count())
# Out:
# Customers: 60
# Policies: 80
# Claims: 80
# Agents: 20

# %%
policies_clean = policies.filter(col("premium") > 0)
claims_clean = claims.filter(col("claim_amount") > 0)

customers_clean = customers.dropna(subset=["customer_id"])

# %%
from pyspark.sql.functions import col, trim

# Remove negatives
policies_clean = policies.filter(col("premium") > 0)
claims_clean = claims.filter(col("claim_amount") > 0)

# Handle nulls
customers_clean = customers.dropna(subset=["customer_id"])

# Standardize strings
customers_clean = customers_clean.withColumn("city", trim(col("city")))

# Rename columns to avoid ambiguity
customers_clean = customers_clean.withColumnRenamed("name", "customer_name")
agents_clean = agents.withColumnRenamed("name", "agent_name")

# %%
policy_agents = spark.createDataFrame([
    (101, 201),
    (102, 202),
    (103, 201)
], ["policy_id", "agent_id"])

# %%
# Invalid policies (no customer)
invalid_policies = policies.join(customers, "customer_id", "left_anti")

# Invalid claims (no policy)
invalid_claims = claims.join(policies, "policy_id", "left_anti")

print("Invalid Policies:", invalid_policies.count())
print("Invalid Claims:", invalid_claims.count())
# Out:
# Invalid Policies: 10
# Invalid Claims: 13

# %%
print("Original Policies:", policies.count())
print("Cleaned Policies:", policies_clean.count())
# Out:
# Original Policies: 80
# Cleaned Policies: 56

# %%
joined_df = customers_clean \
    .join(policies_clean, "customer_id", "inner") \
    .join(claims_clean, "policy_id", "left") \
    .join(policy_agents, "policy_id", "left") \
    .join(agents, "agent_id", "left")

print("Joined Data")
joined_df.show()
# Out:
# Joined Data
# +--------+---------+-----------+------+---+---------+-----------+-------+----------+--------+------------+----------+--------+----+------+
# |agent_id|policy_id|customer_id|  name|age|     city|policy_type|premium|start_date|claim_id|claim_amount|claim_date|  status|name|region|
# +--------+---------+-----------+------+---+---------+-----------+-------+----------+--------+------------+----------+--------+----+------+
# |    NULL|      174|          1| Cust1| 25|Bangalore|       Auto|  10181|2023-03-12|     212|       13997|2023-03-21| Pending|NULL|  NULL|
# |    NULL|      166|          4| Cust4| 58|Hyderabad|     Health|  14924|2023-07-19|    NULL|        NULL|      NULL|    NULL|NULL|  NULL|
# |    NULL|      170|          1| Cust1| 25|Bangalore|       Life|   7256|2023-05-22|     269|        2023|2023-04-20| Pending|NULL|  NULL|
# |    NULL|      127|          4| Cust4| 58|Hyderabad|     Health|   1795|2023-07-08|     231|       10296|2023-04-22|Rejected|NULL|  NULL|
# |    NULL|      170|          1| Cust1| 25|Bangalore|       Life|   7256|2023-05-22|     209|        8158|2023-04-30| Pending|NULL|  NULL|
# |    NULL|      127|          4| Cust4| 58|Hyderabad|     Health|   1795|2023-07-08|     228|       13644|2023-06-14|Approved|NULL|  NULL|
# |    NULL|      170|          1| Cust1| 25|Bangalore|       Life|   7256|2023-05-22|     204|        5569|2023-02-15|Rejected|NULL|  NULL|
# |    NULL|      150|          8| Cust8| 32|  Chennai|     Health|   9978|2023-06-24|     208|        5932|2023-05-22|Approved|NULL|  NULL|
# |    NULL|      110|          9| Cust9| 47|Hyderabad|       Life|  10514|2023-05-10|    NULL|        NULL|      NULL|    NULL|NULL|  NULL|
# |    NULL|      177|         11|Cust11| 42|Hyderabad|       Auto|   5856|2023-03-13|    NULL|        NULL|      NULL|    NULL|NULL|  NULL|
# |    NULL|      151|         12|Cust12| 33|Bangalore|       Life|  15994|2023-01-09|     203|        6667|2023-02-05|Rejected|NULL|  NULL|
# |    NULL|      112|         14|Cust14| 60|   Mumbai|       Life|  16596|2023-10-23|     255|        1432|2023-10-08|Rejected|NULL|  NULL|
# |    NULL|      116|         15|Cust15| 30|Hyderabad|       Auto|  11693|2023-08-18|    NULL|        NULL|      NULL|    NULL|NULL|  NULL|
# |    NULL|      161|         11|Cust11| 42|Hyderabad|     Health|   9652|2023-02-20|     280|        2476|2023-06-27|Rejected|NULL|  NULL|
# |    NULL|      113|         12|Cust12| 33|Bangalore|       Auto|   9760|2023-10-28|    NULL|        NULL|      NULL|    NULL|NULL|  NULL|
# |    NULL|      111|         11|Cust11| 42|Hyderabad|     Health|   6363|2023-02-20|    NULL|        NULL|      NULL|    NULL|NULL|  NULL|
# |    NULL|      150|          8| Cust8| 32|  Chennai|     Health|   9978|2023-06-24|     206|        8459|2023-03-28|Rejected|NULL|  NULL|
# |    NULL|      112|         14|Cust14| 60|   Mumbai|       Life|  16596|2023-10-23|     219|        6109|2023-02-17| Pending|NULL|  NULL|
# |    NULL|      161|         11|Cust11| 42|Hyderabad|     Health|   9652|2023-02-20|     216|        4108|2023-07-07|Approved|NULL|  NULL|
# |    NULL|      152|         16|Cust16| 56|Bangalore|       Life|  11196|2023-10-12|     207|       11831|2023-06-07| Pending|NULL|  NULL|
# +--------+---------+-----------+------+---+---------+-----------+-------+----------+--------+------------+----------+--------+----+------+
# only showing top 20 rows

# %%
customers_clean = customers_clean.withColumnRenamed("name", "customer_name")

# %%
joined_df = customers_clean \
    .join(policies_clean, "customer_id") \
    .join(claims_clean, "policy_id", "left") \
    .join(policy_agents, "policy_id", "left") \
    .join(agents, "agent_id", "left")

# %%
from pyspark.sql.functions import col, sum

agg_df = joined_df.groupBy("customer_id", "customer_name", "city") \
    .agg(
        sum("premium").alias("total_premium"),
        sum("claim_amount").alias("total_claim")
    )

agg_df = agg_df.withColumn(
    "risk_score",
    col("total_claim") / col("total_premium")
)

agg_df.show()
# Out:
# +-----------+-------------+---------+-------------+-----------+-------------------+
# |customer_id|customer_name|     city|total_premium|total_claim|         risk_score|
# +-----------+-------------+---------+-------------+-----------+-------------------+
# |          4|        Cust4|Hyderabad|        18514|      23940| 1.2930755104245435|
# |          1|        Cust1|Bangalore|        31949|      29747| 0.9310776550126765|
# |         11|       Cust11|Hyderabad|        31523|       6584|0.20886336960314691|
# |         12|       Cust12|Bangalore|        25754|       6667| 0.2588724081696047|
# |         15|       Cust15|Hyderabad|        11693|       NULL|               NULL|
# |          9|        Cust9|Hyderabad|        10514|       NULL|               NULL|
# |          8|        Cust8|  Chennai|        19956|      14391| 0.7211365003006615|
# |         14|       Cust14|   Mumbai|        33192|       7541|0.22719329959026272|
# |         18|       Cust18|   Mumbai|        45349|      16999| 0.3748483979801098|
# |         19|       Cust19|Hyderabad|        34772|      36814| 1.0587254112504314|
# |         21|       Cust21|  Chennai|        11391|      17993| 1.5795803704679132|
# |         16|       Cust16|Bangalore|        11196|      11831| 1.0567166845301894|
# |         17|       Cust17|  Chennai|        25389|      20919| 0.8239395013588562|
# |         25|       Cust25|Bangalore|        11188|       NULL|               NULL|
# |         28|       Cust28|Bangalore|        31200|       NULL|               NULL|
# |         32|       Cust32|Bangalore|        23946|      15415| 0.6437400818508311|
# |         34|       Cust34|Bangalore|        16357|       NULL|               NULL|
# |         33|       Cust33|   Mumbai|        15090|       NULL|               NULL|
# |         31|       Cust31|  Chennai|        26511|      12294|0.46373203575874167|
# |         41|       Cust41|  Chennai|        19872|       NULL|               NULL|
# +-----------+-------------+---------+-------------+-----------+-------------------+
# only showing top 20 rows

# %%
city_df = joined_df.groupBy("city") \
    .agg(
        sum("premium").alias("city_premium"),
        sum("claim_amount").alias("city_claim")
    )

city_df.show()
# Out:
# +---------+------------+----------+
# |     city|city_premium|city_claim|
# +---------+------------+----------+
# |Hyderabad|      133324|     74711|
# |Bangalore|      204635|    103231|
# |  Chennai|      161340|    132298|
# |   Mumbai|      160517|     26767|
# +---------+------------+----------+

# %%
window_spec = Window.partitionBy("city").orderBy(col("total_premium").desc())

ranked_df = agg_df.withColumn("rank", dense_rank().over(window_spec))

top_customers = ranked_df.filter(col("rank") <= 2)

print("Top Customers per City")
top_customers.show()
# Out:
# Top Customers per City
# +-----------+-------------+---------+-------------+-----------+-------------------+----+
# |customer_id|customer_name|     city|total_premium|total_claim|         risk_score|rank|
# +-----------+-------------+---------+-------------+-----------+-------------------+----+
# |         47|       Cust47|Bangalore|        33216|      26647| 0.8022338631984586|   1|
# |          1|        Cust1|Bangalore|        31949|      29747| 0.9310776550126765|   2|
# |         31|       Cust31|  Chennai|        26511|      12294|0.46373203575874167|   1|
# |         56|       Cust56|  Chennai|        26280|      28118| 1.0699391171993913|   2|
# |         19|       Cust19|Hyderabad|        34772|      36814| 1.0587254112504314|   1|
# |         11|       Cust11|Hyderabad|        31523|       6584|0.20886336960314691|   2|
# |         18|       Cust18|   Mumbai|        45349|      16999| 0.3748483979801098|   1|
# |         14|       Cust14|   Mumbai|        33192|       7541|0.22719329959026272|   2|
# +-----------+-------------+---------+-------------+-----------+-------------------+----+

# %%
agents.columns
agents = agents.withColumnRenamed("name", "agent_name")

# %%
joined_df = customers_clean \
    .join(policies_clean, "customer_id") \
    .join(claims_clean, "policy_id", "left") \
    .join(policy_agents, "policy_id", "left") \
    .join(agents, "agent_id", "left")

# %%
agent_perf = joined_df.groupBy("agent_id", "agent_name") \
    .agg(sum("premium").alias("total_premium")) \
    .orderBy(col("total_premium").desc())

print("Agent Performance")
agent_perf.show()
# Out:
# Agent Performance
# +--------+----------+-------------+
# |agent_id|agent_name|total_premium|
# +--------+----------+-------------+
# |    NULL|      NULL|       645988|
# |     202|      NULL|        13450|
# |     201|      NULL|          378|
# +--------+----------+-------------+

# %%
joined_df.createOrReplaceTempView("insurance")

spark.sql("""
WITH premium_cte AS (
    SELECT customer_id, SUM(premium) AS total_premium
    FROM insurance
    GROUP BY customer_id
),
claim_cte AS (
    SELECT customer_id, SUM(claim_amount) AS total_claim
    FROM insurance
    GROUP BY customer_id
),
risk_cte AS (
    SELECT p.customer_id,
           p.total_premium,
           c.total_claim,
           (c.total_claim / p.total_premium) AS risk_score
    FROM premium_cte p
    JOIN claim_cte c
    ON p.customer_id = c.customer_id
)
SELECT * FROM risk_cte
""").show()
# Out:
# +-----------+-------------+-----------+-------------------+
# |customer_id|total_premium|total_claim|         risk_score|
# +-----------+-------------+-----------+-------------------+
# |          9|        10514|       NULL|               NULL|
# |         11|        31523|       6584|0.20886336960314691|
# |         17|        25389|      20919| 0.8239395013588562|
# |         46|          378|       7373| 19.505291005291006|
# |         58|         2618|      10908|  4.166539343009931|
# |         53|        16546|       NULL|               NULL|
# |         60|        13450|       NULL|               NULL|
# |         28|        31200|       NULL|               NULL|
# |         14|        33192|       7541|0.22719329959026272|
# |         12|        25754|       6667| 0.2588724081696047|
# |         15|        11693|       NULL|               NULL|
# |         18|        45349|      16999| 0.3748483979801098|
# |          4|        18514|      23940| 1.2930755104245435|
# |         48|        14425|       2227| 0.1543847487001733|
# |         50|        17211|       2016|0.11713439079658358|
# |         34|        16357|       NULL|               NULL|
# |         44|        12480|       NULL|               NULL|
# |         59|         8442|      12838| 1.5207296849087895|
# |         45|        19145|       NULL|               NULL|
# |         43|        16770|       NULL|               NULL|
# +-----------+-------------+-----------+-------------------+
# only showing top 20 rows

# %%
spark.sql("""
WITH risk_data AS (
    SELECT customer_id, city,
           SUM(claim_amount)/SUM(premium) AS risk_score
    FROM insurance
    GROUP BY customer_id, city
),
ranked AS (
    SELECT *,
           DENSE_RANK() OVER (PARTITION BY city ORDER BY risk_score DESC) AS rnk
    FROM risk_data
)
SELECT * FROM ranked WHERE rnk <= 3
""").show()
# Out:
# +-----------+---------+-------------------+---+
# |customer_id|     city|         risk_score|rnk|
# +-----------+---------+-------------------+---+
# |         58|Bangalore|  4.166539343009931|  1|
# |         16|Bangalore| 1.0567166845301894|  2|
# |          1|Bangalore| 0.9310776550126765|  3|
# |         54|  Chennai| 3.9846387575962186|  1|
# |         21|  Chennai| 1.5795803704679132|  2|
# |         59|  Chennai| 1.5207296849087895|  3|
# |         46|Hyderabad| 19.505291005291006|  1|
# |          4|Hyderabad| 1.2930755104245435|  2|
# |         19|Hyderabad| 1.0587254112504314|  3|
# |         18|   Mumbai| 0.3748483979801098|  1|
# |         14|   Mumbai|0.22719329959026272|  2|
# |         48|   Mumbai| 0.1543847487001733|  3|
# +-----------+---------+-------------------+---+

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import dense_rank

# Rank customers by risk
w = Window.partitionBy("city").orderBy(col("risk_score").desc())

ranked_df = agg_df.withColumn("rank", dense_rank().over(w))

ranked_df.show()
# Out:
# +-----------+-------------+---------+-------------+-----------+-------------------+----+
# |customer_id|customer_name|     city|total_premium|total_claim|         risk_score|rank|
# +-----------+-------------+---------+-------------+-----------+-------------------+----+
# |         58|       Cust58|Bangalore|         2618|      10908|  4.166539343009931|   1|
# |         16|       Cust16|Bangalore|        11196|      11831| 1.0567166845301894|   2|
# |          1|        Cust1|Bangalore|        31949|      29747| 0.9310776550126765|   3|
# |         47|       Cust47|Bangalore|        33216|      26647| 0.8022338631984586|   4|
# |         32|       Cust32|Bangalore|        23946|      15415| 0.6437400818508311|   5|
# |         12|       Cust12|Bangalore|        25754|       6667| 0.2588724081696047|   6|
# |         50|       Cust50|Bangalore|        17211|       2016|0.11713439079658358|   7|
# |         25|       Cust25|Bangalore|        11188|       NULL|               NULL|   8|
# |         28|       Cust28|Bangalore|        31200|       NULL|               NULL|   8|
# |         34|       Cust34|Bangalore|        16357|       NULL|               NULL|   8|
# |         54|       Cust54|  Chennai|         5924|      23605| 3.9846387575962186|   1|
# |         21|       Cust21|  Chennai|        11391|      17993| 1.5795803704679132|   2|
# |         59|       Cust59|  Chennai|         8442|      12838| 1.5207296849087895|   3|
# |         56|       Cust56|  Chennai|        26280|      28118| 1.0699391171993913|   4|
# |         17|       Cust17|  Chennai|        25389|      20919| 0.8239395013588562|   5|
# |          8|        Cust8|  Chennai|        19956|      14391| 0.7211365003006615|   6|
# |         31|       Cust31|  Chennai|        26511|      12294|0.46373203575874167|   7|
# |         52|       Cust52|  Chennai|        17575|       2140|0.12176386913229019|   8|
# |         41|       Cust41|  Chennai|        19872|       NULL|               NULL|   9|
# |         46|       Cust46|Hyderabad|          378|       7373| 19.505291005291006|   1|
# +-----------+-------------+---------+-------------+-----------+-------------------+----+
# only showing top 20 rows

# %%
print("Negative Premium Check")
policies_clean.filter(col("premium") < 0).show()
# Out:
# Negative Premium Check
# +---------+-----------+-----------+-------+----------+
# |policy_id|customer_id|policy_type|premium|start_date|
# +---------+-----------+-----------+-------+----------+
# +---------+-----------+-----------+-------+----------+

# %%
print("Negative Claim Check")
claims_clean.filter(col("claim_amount") < 0).show()
# Out:
# Negative Claim Check
# +--------+---------+------------+----------+------+
# |claim_id|policy_id|claim_amount|claim_date|status|
# +--------+---------+------------+----------+------+
# +--------+---------+------------+----------+------+

# %%
print("Null Check")
joined_df.select([count(when(col(c).isNull(), c)).alias(c)
                  for c in joined_df.columns]).display()
# Out:
# Null Check
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>agent_id</th><th>policy_id</th><th>customer_id</th><th>customer_name</th><th>age</th><th>city</th><th>policy_type</th><th>premium</th><th>start_date</th><th>claim_id</th><th>claim_amount</th><th>claim_date</th><th>status</th><th>agent_name</th><th>region</th></tr></thead><tbody><tr><td>63</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>23</td><td>23</td><td>23</td><td>23</td><td>65</td><td>65</td></tr></tbody></table></div>

# %%
# Duplicate check
print("Duplicate Check")
joined_df.groupBy(joined_df.columns).count().filter("count > 1").show()
# Out:
# Duplicate Check
# +--------+---------+-----------+-------------+---+----+-----------+-------+----------+--------+------------+----------+------+----------+------+-----+
# |agent_id|policy_id|customer_id|customer_name|age|city|policy_type|premium|start_date|claim_id|claim_amount|claim_date|status|agent_name|region|count|
# +--------+---------+-----------+-------------+---+----+-----------+-------+----------+--------+------------+----------+------+----------+------+-----+
# +--------+---------+-----------+-------------+---+----+-----------+-------+----------+--------+------------+----------+------+----------+------+-----+

# %%
total1 = joined_df.agg(sum("premium")).collect()[0][0]

total2 = joined_df.groupBy("agent_id") \
    .agg(sum("premium").alias("p")) \
    .agg(sum("p")).collect()[0][0]

print("Total Premium Check:", total1, total2)
# Out:
# Total Premium Check: 659816 659816

# %%
print("Risk Score Check")
agg_df.select("customer_id", "risk_score").display()
# Out:
# Risk Score Check
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>risk_score</th></tr></thead><tbody><tr><td>4</td><td>1.2930755104245435</td></tr><tr><td>1</td><td>0.9310776550126765</td></tr><tr><td>11</td><td>0.20886336960314691</td></tr><tr><td>12</td><td>0.2588724081696047</td></tr><tr><td>15</td><td>null</td></tr><tr><td>9</td><td>null</td></tr><tr><td>8</td><td>0.7211365003006615</td></tr><tr><td>14</td><td>0.22719329959026272</td></tr><tr><td>18</td><td>0.3748483979801098</td></tr><tr><td>19</td><td>1.0587254112504314</td></tr><tr><td>21</td><td>1.5795803704679132</td></tr><tr><td>16</td><td>1.0567166845301894</td></tr><tr><td>17</td><td>0.8239395013588562</td></tr><tr><td>25</td><td>null</td></tr><tr><td>28</td><td>null</td></tr><tr><td>32</td><td>0.6437400818508311</td></tr><tr><td>34</td><td>null</td></tr><tr><td>33</td><td>null</td></tr><tr><td>31</td><td>0.46373203575874167</td></tr><tr><td>41</td><td>null</td></tr><tr><td>44</td><td>null</td></tr><tr><td>43</td><td>null</td></tr><tr><td>45</td><td>null</td></tr><tr><td>47</td><td>0.8022338631984586</td></tr><tr><td>52</td><td>0.12176386913229019</td></tr><tr><td>46</td><td>19.505291005291006</td></tr><tr><td>48</td><td>0.1543847487001733</td></tr><tr><td>50</td><td>0.11713439079658358</td></tr><tr><td>53</td><td>null</td></tr><tr><td>58</td><td>4.166539343009931</td></tr><tr><td>60</td><td>null</td></tr><tr><td>54</td><td>3.9846387575962186</td></tr><tr><td>56</td><td>1.0699391171993913</td></tr><tr><td>59</td><td>1.5207296849087895</td></tr></tbody></table></div>

# %%
print("Final Output")
agg_df.display()
# Out:
# Final Output
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>city</th><th
373</td><td>19.505291005291006</td></tr><tr><td>48</td><td>Cust48</td><td>Mumbai</td><td>14425</td><td>2227</td><td>0.1543847487001733</td></tr><tr><td>50</td><td>Cust50</td><td>Bangalore</td><td>17211</td><td>2016</td><td>0.11713439079658358</td></tr><tr><td>53</td><td>Cust53</td><td>Mumbai</td><td>16546</td><td>null</td><td>null</td></tr><tr><td>58</td><td>Cust58</td><td>Bangalore</td><td>2618</td><td>10908</td><td>4.166539343009931</td></tr><tr><td>60</td><td>Cust60</td><td>Hyderabad</td><td>13450</td><td>null</td><td>null</td></tr><tr><td>54</td><td>Cust54</td><td>Chennai</td><td>5924</td><td>23605</td><td>3.9846387575962186</td></tr><tr><td>56</td><td>Cust56</td><td>Chennai</td><td>26280</td><td>28118</td><td>1.0699391171993913</td></tr><tr><td>59</td><td>Cust59</td><td>Chennai</td><td>8442</td><td>12838</td><td>1.5207296849087895</td></tr></tbody></table></div>

# %%
agent_perf = joined_df.groupBy("agent_id", "agent_name") \
    .agg(sum("premium").alias("total_premium"))

w2 = Window.orderBy(col("total_premium").desc())

agent_rank = agent_perf.withColumn("rank", dense_rank().over(w2))

agent_rank.show()
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# +--------+----------+-------------+----+
# |agent_id|agent_name|total_premium|rank|
# +--------+----------+-------------+----+
# |    NULL|      NULL|       645988|   1|
# |     202|      NULL|        13450|   2|
# |     201|      NULL|          378|   3|
# +--------+----------+-------------+----+

# %%
spark.sql("SHOW TABLES").show()
# Out:
# +--------+-----------------+-----------+
# |database|        tableName|isTemporary|
# +--------+-----------------+-----------+
# | default|      amployees_2|      false|
# | default|        costomers|      false|
# | default| customer_revenue|      false|
# | default|customer_spending|      false|
# | default|   dealer_revenue|      false|
# | default|       delta_demo|      false|
# | default|      departments|      false|
# | default|         employee|      false|
# | default|employee_payments|      false|
# | default|        employees|      false|
# | default|      employees_1|      false|
# | default|      employees_2|      false|
# | default|            jaine|      false|
# | default|     loan_details|      false|
# | default|           olders|      false|
# | default|           orders|      false|
# | default|  orders_delivery|      false|
# | default|    phase6_output|      false|
# | default|         projects|      false|
# | default|   regex_practice|      false|
# +--------+-----------------+-----------+
# only showing top 20 rows

# %%
agg_df.write.mode("overwrite").format("delta").saveAsTable("insurance_output")

# %%
display(agg_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>city</th><th>total_premium</th><th>total_claim</th><th>risk_score</th></tr></thead><tbody><tr><td>4</td><td>Cust4</td><td>Hyderabad</td><td>18514</td><td>23940</td><td>1.2930755104245435</td></tr><tr><td>1</td><td>Cust1</td><td>Bangalore</td><td>31949</td><td>29747</td><td>0.9310776550126765</td></tr><tr><td>11</td><td>Cust11</td><td>Hyderabad</td><td>31523</td><td>6584</td><td>0.20886336960314691</td></tr><tr><td>12</td><td>Cust12</td><td>Bangalore</td><td>25754</td><td>6667</td><td>0.2588724081696047</td></tr><tr><td>15</td><td>Cust15</td><td>Hyderabad</td><td>11693</td><td>null</td><td>null</td></tr><tr><td>9</td><td>Cust9</td><td>Hyderabad</td><td>10514</td><td>null</td><td>null</td></tr><tr><td>8</td><td>Cust8</td