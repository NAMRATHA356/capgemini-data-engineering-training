# %%
# %sql
CREATE or replace TABLE regex_practice (
id INT,
full_text VARCHAR(200),
email VARCHAR(100),
phone VARCHAR(30),
mixed_value VARCHAR(100)
);
INSERT INTO regex_practice VALUES
(1,'EMP001_IN_91','karthik@gmail.com','+91-9876543210','abc123xyz'),
(2,'EMP002_US_01','rahul@yahoo.com','+1-7654321098','test45done'),
(3,'EMP003_UK_44','john@outlook.com','+44-9988776655','run9fast'),
(4,'EMP004_AU_61','steve@gmail.com','+61-8899776655','go88home'),
(5,'EMP005_IN_91','arjun@company.in','+91-7788996655','data77lake'),
(6,'EMP006_US_01','meera@gmail.com','+1-9090909090','spark12sql'),
(7,'EMP007_UK_44','rohan@yahoo.com','+44-7878787878','etl999job'),
(8,'EMP008_AU_61','alice@company.au','+61-6665554443','cloud7aws'),
(9,'EMP009_IN_91','vinay@gmail.com','+91-9988776655','hdfs34node'),
(10,'EMP010_US_01','sam@outlook.com','+1-6767676767','map5reduce'),
(11,'USR11_IN','neha@gmail.com','91-8899001122','abc1'),
(12,'USR12_US','tom@yahoo.com','01-9988776655','x9'),
(13,'USR13_UK','harry@company.co.uk','44-6677889900','z88'),
(14,'USR14_AU','olivia@gmail.com','61-4455667788','q777'),
(15,'USR15_IN','ankit@company.in','91-9988001122','karthik99');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>15</td><td>15</td></tr></tbody></table></div>

# %%
# %sql
SELECT REGEXP_SUBSTR(mixed_value, '^[0-9]+') FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>REGEXP_SUBSTR(mixed_value,'^[0-9]+')</th></tr></thead><tbody><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr></tbody></table></div>

# %%
# %sql
SELECT REGEXP_SUBSTR(mixed_value, '[0-9]+$') FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>REGEXP_SUBSTR(mixed_value,'[0-9]+$')</th></tr></thead><tbody><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>1</td></tr><tr><td>9</td></tr><tr><td>88</td></tr><tr><td>777</td></tr><tr><td>99</td></tr></tbody></table></div>

# %%
# %sql
SELECT REGEXP_SUBSTR(mixed_value, '^.') FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>REGEXP_SUBSTR(mixed_value,'^.')</th></tr></thead><tbody><tr><td>a</td></tr><tr><td>t</td></tr><tr><td>r</td></tr><tr><td>g</td></tr><tr><td>d</td></tr><tr><td>s</td></tr><tr><td>e</td></tr><tr><td>c</td></tr><tr><td>h</td></tr><tr><td>m</td></tr><tr><td>a</td></tr><tr><td>x</td></tr><tr><td>z</td></tr><tr><td>q</td></tr><tr><td>k</td></tr></tbody></table></div>

# %%
# %sql
SELECT REGEXP_SUBSTR(mixed_value, '.$') FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>REGEXP_SUBSTR(mixed_value,'.$')</th></tr></thead><tbody><tr><td>z</td></tr><tr><td>e</td></tr><tr><td>t</td></tr><tr><td>e</td></tr><tr><td>e</td></tr><tr><td>l</td></tr><tr><td>b</td></tr><tr><td>s</td></tr><tr><td>e</td></tr><tr><td>e</td></tr><tr><td>1</td></tr><tr><td>9</td></tr><tr><td>8</td></tr><tr><td>7</td></tr><tr><td>9</td></tr></tbody></table></div>

# %%
# %sql
SELECT REGEXP_SUBSTR(mixed_value, '[0-9]{2}') FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>REGEXP_SUBSTR(mixed_value,'[0-9]{2}')</th></tr></thead><tbody><tr><td>12</td></tr><tr><td>45</td></tr><tr><td>null</td></tr><tr><td>88</td></tr><tr><td>77</td></tr><tr><td>12</td></tr><tr><td>99</td></tr><tr><td>null</td></tr><tr><td>34</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>88</td></tr><tr><td>77</td></tr><tr><td>99</td></tr></tbody></table></div>

# %%
# %sql
SELECT REGEXP_SUBSTR(mixed_value, '[0-9]') FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>REGEXP_SUBSTR(mixed_value,'[0-9]')</th></tr></thead><tbody><tr><td>1</td></tr><tr><td>4</td></tr><tr><td>9</td></tr><tr><td>8</td></tr><tr><td>7</td></tr><tr><td>1</td></tr><tr><td>9</td></tr><tr><td>7</td></tr><tr><td>3</td></tr><tr><td>5</td></tr><tr><td>1</td></tr><tr><td>9</td></tr><tr><td>8</td></tr><tr><td>7</td></tr><tr><td>9</td></tr></tbody></table></div>

# %%
# %sql
SELECT REGEXP_SUBSTR(phone, '^[+]?[0-9]+') FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>REGEXP_SUBSTR(phone,'^[+]?[0-9]+')</th></tr></thead><tbody><tr><td>+91</td></tr><tr><td>+1</td></tr><tr><td>+44</td></tr><tr><td>+61</td></tr><tr><td>+91</td></tr><tr><td>+1</td></tr><tr><td>+44</td></tr><tr><td>+61</td></tr><tr><td>+91</td></tr><tr><td>+1</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr></tbody></table></div>

# %%
# %sql
SELECT REGEXP_SUBSTR(mixed_value, '[0-9]+') FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>REGEXP_SUBSTR(mixed_value,'[0-9]+')</th></tr></thead><tbody><tr><td>123</td></tr><tr><td>45</td></tr><tr><td>9</td></tr><tr><td>88</td></tr><tr><td>77</td></tr><tr><td>12</td></tr><tr><td>999</td></tr><tr><td>7</td></tr><tr><td>34</td></tr><tr><td>5</td></tr><tr><td>1</td></tr><tr><td>9</td></tr><tr><td>88</td></tr><tr><td>777</td></tr><tr><td>99</td></tr></tbody></table></div>

# %%
# %sql
SELECT REGEXP_SUBSTR(email, '^[^@]+') FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>REGEXP_SUBSTR(email,'^[^@]+')</th></tr></thead><tbody><tr><td>karthik</td></tr><tr><td>rahul</td></tr><tr><td>john</td></tr><tr><td>steve</td></tr><tr><td>arjun</td></tr><tr><td>meera</td></tr><tr><td>rohan</td></tr><tr><td>alice</td></tr><tr><td>vinay</td></tr><tr><td>sam</td></tr><tr><td>neha</td></tr><tr><td>tom</td></tr><tr><td>harry</td></tr><tr><td>olivia</td></tr><tr><td>ankit</td></tr></tbody></table></div>

# %%
# %sql
SELECT regexp_extract(email, '@(.+)', 1) FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>regexp_extract(email,'@(.+)',1)</th></tr></thead><tbody><tr><td>gmail.com</td></tr><tr><td>yahoo.com</td></tr><tr><td>outlook.com</td></tr><tr><td>gmail.com</td></tr><tr><td>company.in</td></tr><tr><td>gmail.com</td></tr><tr><td>yahoo.com</td></tr><tr><td>company.au</td></tr><tr><td>gmail.com</td></tr><tr><td>outlook.com</td></tr><tr><td>gmail.com</td></tr><tr><td>yahoo.com</td></tr><tr><td>company.co.uk</td></tr><tr><td>gmail.com</td></tr><tr><td>company.in</td></tr></tbody></table></div>

# %%
# %sql
SELECT regexp_extract(email, '@([^\\.]+)', 1) FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>regexp_extract(email,'@([^\\.]+)',1)</th></tr></thead><tbody><tr><td>gmail</td></tr><tr><td>yahoo</td></tr><tr><td>outlook</td></tr><tr><td>gmail</td></tr><tr><td>company</td></tr><tr><td>gmail</td></tr><tr><td>yahoo</td></tr><tr><td>company</td></tr><tr><td>gmail</td></tr><tr><td>outlook</td></tr><tr><td>gmail</td></tr><tr><td>yahoo</td></tr><tr><td>company</td></tr><tr><td>gmail</td></tr><tr><td>company</td></tr></tbody></table></div>

# %%
# %sql
SELECT regexp_extract(email, '\\.([^\\.]+)$', 1) FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>regexp_extract(email,'\\.([^\\.]+)$',1)</th></tr></thead><tbody><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>in</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>au</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>uk</td></tr><tr><td>com</td></tr><tr><td>in</td></tr></tbody></table></div>

# %%
# %sql
SELECT regexp_extract(mixed_value, '[A-Za-z]+', 0) FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>regexp_extract(mixed_value,'[A-Za-z]+',0)</th></tr></thead><tbody><tr><td>abc</td></tr><tr><td>test</td></tr><tr><td>run</td></tr><tr><td>go</td></tr><tr><td>data</td></tr><tr><td>spark</td></tr><tr><td>etl</td></tr><tr><td>cloud</td></tr><tr><td>hdfs</td></tr><tr><td>map</td></tr><tr><td>abc</td></tr><tr><td>x</td></tr><tr><td>z</td></tr><tr><td>q</td></tr><tr><td>karthik</td></tr></tbody></table></div>

# %%
# %sql
SELECT regexp_extract(mixed_value, '[0-9]+', 0) FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>regexp_extract(mixed_value,'[0-9]+',0)</th></tr></thead><tbody><tr><td>123</td></tr><tr><td>45</td></tr><tr><td>9</td></tr><tr><td>88</td></tr><tr><td>77</td></tr><tr><td>12</td></tr><tr><td>999</td></tr><tr><td>7</td></tr><tr><td>34</td></tr><tr><td>5</td></tr><tr><td>1</td></tr><tr><td>9</td></tr><tr><td>88</td></tr><tr><td>777</td></tr><tr><td>99</td></tr></tbody></table></div>

# %%
# %sql
SELECT substr(full_text, 1, 3) FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>substr(full_text,1,3)</th></tr></thead><tbody><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>USR</td></tr><tr><td>USR</td></tr><tr><td>USR</td></tr><tr><td>USR</td></tr><tr><td>USR</td></tr></tbody></table></div>

# %%
# %sql
SELECT right(full_text, 2) FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>RIGHT(full_text,2)</th></tr></thead><tbody><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>IN</td></tr><tr><td>US</td></tr><tr><td>UK</td></tr><tr><td>AU</td></tr><tr><td>IN</td></tr></tbody></table></div>

# %%
# %sql
SELECT regexp_extract(full_text, '[0-9]+', 0) FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>regexp_extract(full_text,'[0-9]+',0)</th></tr></thead><tbody><tr><td>001</td></tr><tr><td>002</td></tr><tr><td>003</td></tr><tr><td>004</td></tr><tr><td>005</td></tr><tr><td>006</td></tr><tr><td>007</td></tr><tr><td>008</td></tr><tr><td>009</td></tr><tr><td>010</td></tr><tr><td>11</td></tr><tr><td>12</td></tr><tr><td>13</td></tr><tr><td>14</td></tr><tr><td>15</td></tr></tbody></table></div>

# %%
# %sql
SELECT regexp_extract(full_text, '([0-9]+)$', 1) FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>regexp_extract(full_text,'([0-9]+)$',1)</th></tr></thead><tbody><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td></td></tr><tr><td></td></tr><tr><td></td></tr><tr><td></td></tr><tr><td></td></tr></tbody></table></div>

# %%
# %sql
SELECT regexp_extract(full_text, '_([^_]+)_', 1) FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>regexp_extract(full_text,'_([^_]+)_',1)</th></tr></thead><tbody><tr><td>IN</td></tr><tr><td>US</td></tr><tr><td>UK</td></tr><tr><td>AU</td></tr><tr><td>IN</td></tr><tr><td>US</td></tr><tr><td>UK</td></tr><tr><td>AU</td></tr><tr><td>IN</td></tr><tr><td>US</td></tr><tr><td></td></tr><tr><td></td></tr><tr><td></td></tr><tr><td></td></tr><tr><td></td></tr></tbody></table></div>

# %%
# %sql
SELECT regexp_extract(phone, '^\\+([0-9]+)', 1) FROM regex_practice;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>regexp_extract(phone,'^\\+([0-9]+)',1)</th></tr></thead><tbody><tr><td>91</td></tr><tr><td>1</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>1</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>1</td></tr><tr><td></td></tr><tr><td></td></tr><tr><td></td></tr><tr><td></td></tr><tr><td></td></tr></tbody></table></div>
